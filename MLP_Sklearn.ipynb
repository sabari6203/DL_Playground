# %% [markdown]
# # Load the data

# %%
import gzip
import pickle
import numpy as np

# Replace this with the correct path to your mnist.pkl.gz
with gzip.open('mnist.pkl.gz', 'rb') as f:
    train_set, valid_set, test_set = pickle.load(f, encoding='latin1')

# Unpack data
X_train, y_train = train_set
X_valid, y_valid = valid_set
X_test, y_test = test_set

# %% [markdown]
# # Train with MLP classifier

# %%
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import classification_report, accuracy_score

# Combine train and validation data for better training
X_train_full = np.vstack((X_train, X_valid))
y_train_full = np.concatenate((y_train, y_valid))

# Initialize MLPClassifier
clf = MLPClassifier(hidden_layer_sizes=(100,), activation='relu', solver='adam', 
                    max_iter=20, batch_size=64, verbose=True, random_state=42)

# Fit the model
clf.fit(X_train_full, y_train_full)
# Out:
# Iteration 1, loss = 0.32567109
# Iteration 2, loss = 0.15118086
# Iteration 3, loss = 0.10784872
# Iteration 4, loss = 0.08256767
# Iteration 5, loss = 0.06795780
# Iteration 6, loss = 0.05537505
# Iteration 7, loss = 0.04631097
# Iteration 8, loss = 0.03851022
# Iteration 9, loss = 0.03285637
# Iteration 10, loss = 0.02790216
# Iteration 11, loss = 0.02311150
# Iteration 12, loss = 0.02035460
# Iteration 13, loss = 0.01771240
# Iteration 14, loss = 0.01528072
# Iteration 15, loss = 0.01270890
# Iteration 16, loss = 0.01179482
# Iteration 17, loss = 0.01129916
# Iteration 18, loss = 0.00902345
# Iteration 19, loss = 0.00845195
# Iteration 20, loss = 0.00718381
# C:\Users\sabar\anaconda3\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (20) reached and the optimization hasn't converged yet.
#   warnings.warn(
# MLPClassifier(batch_size=64, max_iter=20, random_state=42, verbose=True)

# %% [markdown]
# # Evaluate on Test data

# %%
# Predict on test data
y_pred = clf.predict(X_test)

# Print performance metrics
print("Test Accuracy:", accuracy_score(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# Test Accuracy: 0.9786
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.99       980
#            1       0.99      0.99      0.99      1135
#            2       0.97      0.98      0.98      1032
#            3       0.97      0.98      0.98      1010
#            4       0.98      0.97      0.97       982
#            5       0.98      0.98      0.98       892
#            6       0.99      0.97      0.98       958
#            7       0.97      0.98      0.98      1028
#            8       0.97      0.96      0.97       974
#            9       0.97      0.97      0.97      1009
#
#     accuracy                           0.98     10000
#    macro avg       0.98      0.98      0.98     10000
# weighted avg       0.98      0.98      0.98     10000
